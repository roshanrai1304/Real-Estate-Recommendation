# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\mihir project\ML model\processed_real_estate_data.csv")
df.head()
# Out:
#    Unnamed: 0 Builder Name       State District  Location  Highway (mtrs)  \
# 0           0  Dem Phoenix  Maharastra   Mumbai       0.0             900
# 1           1  Dem Phoenix  Maharastra   Mumbai       0.0             900
# 2           2  Dem Phoenix  Maharastra   Mumbai       0.0             900
# 3           3  Dem Phoenix  Maharastra   Mumbai       0.0             900
# 4           4  Dem Phoenix  Maharastra   Mumbai       0.0             900
#
#    Railway (mtrs)  Metro (mtrs)  Bus Stop (mtrs)  \
# 0            2000          1000           1000.0
# 1            2000          1000           1000.0
# 2            2000          1000           1000.0
# 3            2000          1000           1000.0
# 4            2000          1000           1000.0
#
#    Closest Educational Institute Distance (m)  ...  Parking  \
# 0                                      1000.0  ...        1
# 1                                      1000.0  ...        1
# ...

# %%
df = df.iloc[:,1:]

# %%
df.drop(["Builder Name", "State", "District"], axis=1, inplace=True)

# %%
df
# Out:
#       Location  Highway (mtrs)  Railway (mtrs)  Metro (mtrs)  Bus Stop (mtrs)  \
# 0          0.0             900            2000          1000           1000.0
# 1          0.0             900            2000          1000           1000.0
# 2          0.0             900            2000          1000           1000.0
# 3          0.0             900            2000          1000           1000.0
# 4          0.0             900            2000          1000           1000.0
# ...        ...             ...             ...           ...              ...
# 1039       3.0            2000            2000          2600            500.0
# 1040       3.0            2000            2000          2600            500.0
# 1041       3.0            2000            2000          2600            500.0
# 1042       3.0            2000            2000          2600            500.0
# 1043       3.0            2000            2000          2600            500.0
#
# ...

# %%
df.shape
# Out:
# (1044, 23)

# %% [markdown]
# ####
